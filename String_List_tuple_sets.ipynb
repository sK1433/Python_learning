# %% [markdown]
# String is a data type and its immutable

# %%
letter = 'P'   # A string could be a single character or a bunch of texts
print(letter)               # P
print(len(letter))          # 1
greeting = 'Hello, World!'  # String could be made using a single or double quote,"Hello, World!"
print(greeting)             # Hello, World!
print(len(greeting))        # 13
sentence = "I hope you are enjoying the course"
print(sentence)
# Out:
# P
# 1
# Hello, World!
# 13
# I hope you are enjoying the course

# %%
multiline_string = '''I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python.'''
print(multiline_string)
print(type(multiline_string))
# Another way of doing the same thing
multiline_string = """I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python."""
print(multiline_string)
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.
# <class 'str'>
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %%
##String Concatenation  :
name1 = 'I love'
name2 = 'my India'
space = ' '
full_name =  name1  +  space +  name2
print(full_name)
# Out:
# I love my India

# %%
############### Escape Sequences \n: new line \t: Tab means(8 spaces) \\: Back slash \': Single quote (') \": Double quote (")
print('I hope everyone is enjoying the Python course.\nAre you ?') # line break
print('Days\tTopics\tExercises') # adding tab space or 4 spaces
print('Day 1\t5\t5')
print('Day 2\t6\t20')
print('Day 3\t5\t23')
print('Day 4\t1\t35')
print('This is a backslash  symbol (\\)') # To write a backslash
print('In every programming language it starts with \'Hello, World!\'')
print('In every programming language it starts with \"Hello, World!\"')
# Out:
# I hope everyone is enjoying the Python course.
# Are you ?
# Days	Topics	Exercises
# Day 1	5	5
# Day 2	6	20
# Day 3	5	23
# Day 4	1	35
# This is a backslash  symbol (\)
# In every programming language it starts with 'Hello, World!'
# In every programming language it starts with "Hello, World!"

# %%
#########String formatting
a,b,c = 4,3,a+b
formated_string = 'If a= {} and b= {}. (a+b)= {}'.format(a, b, c)
print(formated_string)
print('{} + {} = {}'.format(a, b, a + b))
# Out:
# If a= 4 and b= 3. (a+b)= 7
# 4 + 3 = 7

# %%
##String Concatenation  :
first_name = 'I love'
last_name = 'my India'
space = ' '
full_name = first_name  +  space + last_name
print(full_name)
############### Escape Sequences \n: new line \t: Tab means(8 spaces) \\: Back slash \': Single quote (') \": Double quote (")
print('I hope everyone is enjoying the Python course.\nAre you ?') # line break
print('Days\tTopics\tExercises') # adding tab space or 4 spaces
print('Day 1\t5\t5')
print('Day 2\t6\t20')
print('Day 3\t5\t23')
print('Day 4\t1\t35')
print('This is a backslash  symbol (\\)') # To write a backslash
print('In every programming language it starts with \"Hello, World!\"')

#########String formatting
a,b,c = 4,3,a+b
formated_string = 'If a= {} and b= {}. (a+b)= {}'.format(a, b, c)
print(formated_string)
print('{} + {} = {}'.format(a, b, a + b))
# Out:
# I love my India
# I hope everyone is enjoying the Python course.
# Are you ?
# Days	Topics	Exercises
# Day 1	5	5
# Day 2	6	20
# Day 3	5	23
# Day 4	1	35
# This is a backslash  symbol (\)
# In every programming language it starts with "Hello, World!"
# If a= 4 and b= 3. (a+b)= 7
# 4 + 3 = 7

# %%
 '''
##Strings as Sequences of Characters
language = 'Python'
a,b,c,d,e,f = language # unpacking sequence characters into variables
print(a,b,c) # P y t
#Strings by Index [P,Y,T,H,O,N] [0,1,2,3,4,5] [-6,-5,-4,-3,-2,-1]
print(language[0],language[1],language[5]) # P y n
print(language[-1],language[-2],language[-6]) # n o p
#Slicing Python Strings
print(language[0:3])
print(language[-3:])
print(language[::-1],language[::-2] ,language[0:6:2])
'''

##String Methods
language = 'Pythony iS goat'
#print(language.capitalize(),language.count('y'),language.endswith('on'),language.find('y'),language.rfind('y'))
#print(language.startswith('python') , language.swapcase(),language.title(),language.split(' '),language.replace('python', 'coding'))
print('sandeep'.isupper())
print('sandeep'.islower())
print('sandeep'.isidentifier())
num = '10.5'
print(num.isnumeric()) 
#num = '\u00BD' # ½
#print(num.isnumeric()) # True
# Out:
# False
# True
# True
# False

# %%
language = 'Python'
language[1] = A
print(language[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 language = 'Python'
# ----> 2 language[1] = A
#       3 print(language[1])
#
# NameError: name 'A' is not defined

# %%
test = 'pythonyisgreat'
print(test.isalnum()) # True

test = 'Pythonisgr8'
print(test.isalnum()) # True

test = 'python is great'
print(test.isalnum()) # False, space is not an alphanumeric character

test = 'python is great 2026'
print(test.isalnum()) # False

test = '\u00B2'
print(test.isdigit())  

test = 'python is great'
print(test.isalpha()) # False, space is once again excluded
test = 'pythonisgreat'
print(test.isalpha()) # True
num = '123'
print(num.isalpha())      # False
# Out:
# True
# True
# False
# False
# True
# False
# True
# False

# %%
test = '123.00'
print(test.isdigit(),test.isnumeric(),test.isdecimal())
# Out:
# False False False
